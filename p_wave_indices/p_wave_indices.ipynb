# %%
import pandas as pd
from pandarallel import pandarallel
from p_wave_indices_utils import *
import os

# %%
path_to_ecg_folder = "/mnt/cat/jdeseo/ECG_FM/CODE15/Processed/preprocessed/"

# %%
features = process_dataset(path_to_ecg_folder)
# Out:
# Working on ECG 0 of 66894
# No P waves
# /home/jdeseo/miniconda3/envs/ac_ecg/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jdeseo/miniconda3/envs/ac_ecg/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/jdeseo/miniconda3/envs/ac_ecg/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# No P waves
# No P waves
# /home/jdeseo/miniconda3/envs/ac_ecg/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jdeseo/miniconda3/envs/ac_ecg/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
# ...

# %%
p_wave_indices = pd.DataFrame(list(res_parallel))

# %%
#Multiply amplitude with resolution to get amplitude in microvolt
p_wave_indices["P_amp_II"] = p_wave_indices["P_amp_leadII"] * p_wave_indices["Resolution"]
